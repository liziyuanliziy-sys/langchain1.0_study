# %% [markdown]
# ### 1.安装

# %%
! pip install -U langchain

# %%
# # 安装特定的独立LLM集成
! pip install -U langchain-deepseek

# %% [markdown]
# ### 2.入门例子

# %%
from langchain.agents import create_agent
# from dotenv import load_dotenv
# load_dotenv()

def get_weather(city):
    """
    给一个城市的名字来查询天气
    """
    return f"{city}的天气是晴天！"

agent = create_agent(
    # model的deepseek需要把api_key放进环境变量中，然后重启ide或者jupyter notebook
    # 或者把api_key放进同级目录.env文件（自己创建）中，如上使用load_dotenv()
    model='deepseek-chat',
    tools=[get_weather],
    system_prompt="你是一个优秀的AI助手，请根据用户提出的问题进行回答"
)

result = agent.invoke(
    {"messages": [{"role":"user", "content":"请问北京的天气如何？"}]}
)
result
# Out:
# {'messages': [HumanMessage(content='请问北京的天气如何？', additional_kwargs={}, response_metadata={}, id='8592a5c3-82d4-46b7-b961-4ec5235e0d96'),
#   AIMessage(content='我来帮您查询北京的天气情况。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 161, 'total_tokens': 189, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 161}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '9d495503-179b-4aae-9e42-3f3a06540af3', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--0400c132-271e-40c8-9737-fcc4a1df4374-0', tool_calls=[{'name': 'get_weather', 'args': {'city': '北京'}, 'id': 'call_00_5JEhbhBWqESQ11EiT8T7zeej', 'type': 'tool_call'}], usage_metadata={'input_tokens': 161, 'output_tokens': 28, 'total_tokens': 189, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}),
#   ToolMessage(content='北京的天气是晴天！', name='get_weather', id='7e46498e-adcc-4d97-94d0-605684e9c90c', tool_call_id='call_00_5JEhbhBWqESQ11EiT8T7zeej'),
#   AIMessage(content='根据查询结果，北京今天的天气是晴天！☀️\n\n这是一个很好的天气，适合外出活动。如果您计划在北京出行，建议：\n- 享受户外活动\n- 注意防晒\n- 适当补充水分\n\n希望这个天气信息对您有帮助！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 191, 'total_tokens': 245, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 128}, 'prompt_cache_hit_tokens': 128, 'prompt_cache_miss_tokens': 63}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '3408c68e-7769-4a8e-9371-176574de0ef6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--22987a59-5475-4880-9dbf-e3e69a39e69f-0', usage_metadata={'input_tokens': 191, 'output_tokens': 54, 'total_tokens': 245, 'input_token_details': {'cache_read': 128}, 'output_token_details': {}})]}

# %%
for chunk in result["messages"]:
    chunk.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 请问北京的天气如何？
# ================================== Ai Message ==================================
#
# 我来帮您查询北京的天气情况。
# Tool Calls:
#   get_weather (call_00_5JEhbhBWqESQ11EiT8T7zeej)
#  Call ID: call_00_5JEhbhBWqESQ11EiT8T7zeej
#   Args:
#     city: 北京
# ================================= Tool Message =================================
# Name: get_weather
#
# 北京的天气是晴天！
# ================================== Ai Message ==================================
#
# 根据查询结果，北京今天的天气是晴天！☀️
#
# 这是一个很好的天气，适合外出活动。如果您计划在北京出行，建议：
# - 享受户外活动
# - 注意防晒
# - 适当补充水分
#
# 希望这个天气信息对您有帮助！

# %%
for chunk in agent.stream(
    {"messages": [{"role":"user", "content":"请问北京和上海的天气如何，并对比两地天气"}]}, stream_mode='values'
):
    chunk["messages"][-1].pretty_print()

# 下面的显示是只返回一个上海天气，实际chunks中可以看到返回了两个地方的天气
# Out:
# ================================ Human Message =================================
#
# 请问北京和上海的天气如何，并对比两地天气
# ================================== Ai Message ==================================
#
# 我来帮您查询北京和上海的天气情况，并进行对比。
# Tool Calls:
#   get_weather (call_00_sMC0jPZ1W8wTJcIYkCh1Nilu)
#  Call ID: call_00_sMC0jPZ1W8wTJcIYkCh1Nilu
#   Args:
#     city: 北京
#   get_weather (call_01_vIM9G4aUu8bg889QX3DNrPCS)
#  Call ID: call_01_vIM9G4aUu8bg889QX3DNrPCS
#   Args:
#     city: 上海
# ================================= Tool Message =================================
# Name: get_weather
#
# 上海的天气是晴天！
# ================================== Ai Message ==================================
#
# 根据查询结果，北京和上海两地的天气情况如下：
#
# **北京天气**：晴天 ☀️
#
# **上海天气**：晴天 ☀️
#
# **天气对比分析**：
#
# 1. **相同点**：
#    - 两地都是晴天，天气状况非常相似
#    - 都适合户外活动和出行
#
# 2. **差异点**：
#    - 由于无法获取具体的温度、湿度、风力等详细信息，暂时无法进行更细致的对比
#    - 北京作为北方城市，通常昼夜温差较大
#    - 上海作为沿海城市，湿度可能相对较高
#
# **出行建议**：
# - 两地都是晴天，非常适合旅游和户外活动
# - 建议根据个人体感准备适当的防晒措施
# - 如果需要进行更详细的对比，建议查询具体的温度、湿度等气象数据
#
# 总体来说，北京和上海今天都是好天气，选择哪个城市出行都可以享受到晴朗的天气！

# %%
chunk
# Out:
# "{'messages': [HumanMessage(content='请问北京和上海的天气如何，并对比两地天气', additional_kwargs={}, response_metadata={}, id='891abed1-5d33-494c-9ffa-caa0c2790674'), AIMessage(content='我来帮您查询北京和上海的天气情况，并进行对比。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 167, 'total_tokens': 220, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 128}, 'prompt_cache_hit_tokens': 128, 'prompt_cache_miss_tokens': 39}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '3c1d270f-c575-43c1-b80d-fe9d151fed88', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bbb9e697-76ec-4e6a-84b3-5906544ecf08-0', tool_calls=[{'name': 'get_weather', 'args': {'city': '北京'}, 'id': 'call_00_sMC0jPZ1W8wTJcIYkCh1Nilu', 'type': 'tool_call'}, {'name': 'get_weather', 'args': {'city': '上海'}, 'id': 'call_01_vIM9G4aUu8bg889QX3DNrPCS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 167, 'output_tokens': 53, 'total_tokens': 220, 'input_token_details': {'cache_read': 128}, 'output_token_details': {}}), ToolMessage(content='北京的天气是晴天！', name='get_weather', id='b629699d-4767-4b20-b60c-6318547155f3', tool_call_id='call_00_sMC0jPZ1W8wTJcIYkCh1Nilu'), ToolMessage(content='上海的天气是晴天！', name='get_weather', id='237ef8c0-b1d9-429b-b356-b4c8c1a51ce5', tool_call_id='call_01_vIM9G4aUu8bg889QX3DNrPCS'), AIMessage(content='根据查询结果，北京和上海两地的天气情况如下：\\n\\n**北京天气**：晴天 ☀️\\n\\n**上海天气**：晴天 ☀️\\n\\n**天气对比分析**：\\n\\n1. **相同点**：\\n   - 两地都是晴天，天气状况非常相似\\n   - 都适合户外活动和出行\\n\\n2. **差异点**：\\n   - 由于无法获取具体的温度、湿度、风力等详细信息，暂时无法进行更细致的对比\\n   - 北京作为北方城市，通常昼夜温差较大\\n   - 上海作为沿海城市，湿度可能相对较高\\n\\n**出行建议**：\\n- 两地都是晴天，非常适合旅游和户外活动\\n- 建议根据个人体感准备适当的防晒措施\\n- 如果需要进行更详细的对比，建议查询具体的温度、湿度等气象数据\\n\\n总体来说，北京和上海今天都是好天气，选择哪个城市出行都可以享受到晴朗的天气！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 221, 'total_tokens': 410, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 192}, 'prompt_cache_hit_tokens': 192, 'prompt_cache_miss_tokens': 29}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': 'b7477177-7ca4-4b25-aabe-7e36aba482d1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ea0e26db-7396-4d6d-b74f-c8a1d981ca8b-0', usage_metadata={'input_tokens': 221, 'output_tokens': 189, 'total_tokens': 410, 'input_token_details': {'cache_read': 192}, 'output_token_details': {}})]}"

# %% [markdown]
# ### 3 快速入门案例

# %% [markdown]
# #### 3.1 详细的系统提示

# %%
SYSTEM_PROMPT="""您是一位擅长用双关语进行天气预报的专家。

您可使用两种工具：

- get_weather：用于获取特定地点的天气信息

- get_user_location：用于获取用户所在位置

当用户询问天气时，请确保明确地点。若能从问题中判断用户意指其当前位置，请使用get_user_location工具获取位置信息。
"""

# %% [markdown]
# #### 3.2 工具的创建

# %%
from dataclasses import dataclass
from langchain.tools import tool, ToolRuntime

# dataclass 主要作用是 自动帮你生成一些常见的魔术方法 __init__ __repr__ __eq__
# ToolRuntime 用于在调用工具时，携带额外的上下文信息（例如用户信息、环境变量、请求 ID 等）。

@tool
def get_weather(city):
    """根据city获取当前city的天气"""
    return f"{city}的天气是晴天！"

@dataclass
class Context():
    """自定义运行时上下文模式"""
    user_id: str

@tool
def get_user_location(runtime: ToolRuntime[Context]):
    """根据用户ID检索用户信息"""
    user_id = runtime.context.user_id
    return "上海" if user_id == "1" else "北京"

# %% [markdown]
# #### 3.3 模型配置

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model='deepseek-chat',
    model_provider='deepseek',
    temperature=0.7, 
    timeout=30,
    max_tokens=1000
)

# %% [markdown]
# #### 3.4 结构化输出

# %%
from dataclasses import dataclass

@dataclass
class ResponseFormat:
    """agent的响应格式"""
    # 一个punny的回应
    punny_response: str
    # 如有任何关于天气的有趣信息
    weather_conditions: str | None = None

# %% [markdown]
# #### 3.5 记忆功能

# %%
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %% [markdown]
# #### 3.6 构建Agent

# %%
agent = create_agent(
    model=model,
    system_prompt=SYSTEM_PROMPT,
    tools=[get_weather, get_user_location],
    response_format=ResponseFormat,
    context_schema=Context,
    checkpointer=checkpointer
)

# 创建线程，写入线程id
config = {"configurable": {"thread_id":"1"}}

response = agent.invoke(
    {"messages":[{"role":"user", "content":"现在外面的天气怎么样？"}]},
    config=config,
    context=Context(user_id="1")
)
# print(response)
print(response['structured_response'])
# Out:
# ResponseFormat(punny_response="上海现在阳光明媚，天气真是'晴'不自禁！这样的好天气让人心情'晴'朗，出门记得带上好心情哦～", weather_conditions='晴天')

# %%
# 因为添加了记忆功能，所以可以继续进行连贯提问回答。
response = agent.invoke(
    {"messages": [{"role": "user", "content": "thank you!"}]},
    config=config,
    context=Context(user_id="1")
)

print(response['structured_response'])
# Out:
# ResponseFormat(punny_response="不客气！很高兴能为您'预报'天气～希望我的双关语没有让您'云'里雾里，下次需要天气信息时，我随时'雨'您同在！", weather_conditions=None)
